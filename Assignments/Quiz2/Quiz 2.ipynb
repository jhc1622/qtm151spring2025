# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print("Jack Chapon")
# Out:
# Jack Chapon

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code
fifa = pd.read_csv("data_quiz/fifa23_players_basic.csv") 
fifa
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            Left
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# ...                                                 ...  ...             ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...           Right
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...           Right
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 0                     Low                 Low
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 4                    High                 Low
# ...                   ...                 ...
# 18534              Medium              Medium
# 18535              Medium              Medium
# 18536                High              Medium
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Use queries
#
# <font size = "3">
#
# - Browse the dataset and search for the height variable in cm (centimeters).
#
# - Subset the players whose value of the height variable is above 175 <br>
# and store it in a new dataset
# - How many players are above this height threshold?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. See example provided.

# %%
# Write your own code

# Example: The following code filters whether 
# observations for which `On Loan` is equal to yes
# dataset.query(' `On Loan` == "YES" ')
# Note: be careful with using backward quotations ` here.
# Now apply this to your own example, and calculate the total number of observations.
tall = fifa.query('`Height(in cm)` > 175')
display(tall)
print(len(tall))
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# 6               6     T. Courtois    Thibaut Courtois       90         91
# ...           ...             ...                 ...      ...        ...
# 18530       18530          S. Bag           Sajal Bag       48         61
# 18531       18531        Liao Wei            Wei Liao       48         54
# 18532       18532        H. Singh   Harmanpreet Singh       48         56
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# 6            90000000               GK            GK              Belgium
# ...               ...              ...           ...                  ...
# 18530          110000            CM,RM            RM                India
# 18531           70000            RM,LM           CDM             China PR
# 18532          100000               ST            ST                India
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Preferred Foot  \
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...           Right
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...           Right
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...           Right
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...           Right
# 6      https://cdn.sofifa.net/players/192/119/23_60.png  ...            Left
# ...                                                 ...  ...             ...
# 18530  https://cdn.sofifa.net/players/270/739/23_60.png  ...           Right
# 18531  https://cdn.sofifa.net/players/257/691/23_60.png  ...           Right
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png  ...           Right
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...           Right
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            Left
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# 6                     3            1                         4
# ...                 ...          ...                       ...
# 18530                 4            2                         1
# 18531                 3            2                         1
# 18532                 2            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# 6                 Belgium  https://cdn.sofifa.net/flags/be.png
# ...                   ...                                  ...
# 18530                   -                                    -
# 18531                   -                                    -
# 18532                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# 6                          GK                            1
# ...                       ...                          ...
# 18530                       -                            -
# 18531                       -                            -
# 18532                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate
# 1                  Medium              Medium
# 2                    High              Medium
# 3                    High                High
# 4                    High                 Low
# 6                  Medium              Medium
# ...                   ...                 ...
# 18530              Medium              Medium
# 18531              Medium              Medium
# 18532              Medium                 Low
# 18537              Medium              Medium
# 18538              Medium              Medium
#
# [14653 rows x 33 columns]
# 14653

# %% [markdown]
# <font size = "5">
#
# (b) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Contract Until" shows the date in which a player's contract will expire.
# - Use ".sort_values()" to order the "Contract Until" column <br>
# from later dates to earlier dates.
# - Get a subset with the 5 players in the dataset <br>
# whose contracts will expire later.
# - From this subset, display the names and year in which the contract will expire.
#
# Your output should look something like this:
#
# | Full Name | Contract Until |
# | -------- | ------- |
# | José Luis García Vayá | 2032
# | José Luis García Vayá | 2032
# | Jon Moncayola Tollar | 2031
# | Jon Moncayloa Tollar | 2031
# | Josip Sutalo | 2028
# | Aurelien Tchouaméni | 2028

# %%
# Write your own code
contractsort = fifa.sort_values(by = "Contract Until", ascending = False)
display(contractsort)
sorted = contractsort.iloc[0:6][["Full Name", "Contract Until"]]
sorted
# Out:
#       Unnamed: 0     Known As              Full Name  Overall  Potential  \
# 1876        1876       Pepelu  Jose Luís García Vayá       75         81
# 1806        1806       Pepelu  Jose Luís García Vayá       75         81
# 1478        1478    Moncayola   Jon Moncayola Tollar       75         81
# 1523        1523    Moncayola   Jon Moncayola Tollar       75         81
# 1649        1649    J. Šutalo           Josip Šutalo       75         84
# ...          ...          ...                    ...      ...        ...
# 9943        9943    M. Kheder           Musab Kheder       65         65
# 3505        3505   K. Boudiaf          Karim Boudiaf       72         72
# 4961        4961      Á. Lang              Ádám Lang       70         70
# 8254        8254  I. Mohammad        Ismael Mohammad       67         67
# 1901        1901  J. Gallardo         Jesús Gallardo       75         75
#
#       Value(in Euro) Positions Played Best Position Nationality  \
# 1876         9000000           CM,CDM            CM       Spain
# 1806         9000000           CM,CDM            CM       Spain
# 1478         9000000           CM,CDM            CM       Spain
# 1523         9000000           CM,CDM            CM       Spain
# 1649        12000000               CB            CB     Croatia
# ...              ...              ...           ...         ...
# 9943               0           RWB,CB           RWB       Qatar
# 3505               0           CM,CDM            CM       Qatar
# 4961               0               CB            CB     Hungary
# 8254               0           RWB,RW           RWB       Qatar
# 1901               0         LB,LM,LW            LB      Mexico
#
#                                             Image Link  ...  Preferred Foot  \
# 1876  https://cdn.sofifa.net/players/230/786/23_60.png  ...           Right
# 1806  https://cdn.sofifa.net/players/230/786/23_60.png  ...           Right
# 1478  https://cdn.sofifa.net/players/247/495/23_60.png  ...           Right
# 1523  https://cdn.sofifa.net/players/247/495/23_60.png  ...           Right
# 1649  https://cdn.sofifa.net/players/256/325/23_60.png  ...           Right
# ...                                                ...  ...             ...
# 9943  https://cdn.sofifa.net/players/268/784/23_60.png  ...           Right
# 3505  https://cdn.sofifa.net/players/268/778/23_60.png  ...           Right
# 4961  https://cdn.sofifa.net/players/223/207/23_60.png  ...           Right
# 8254  https://cdn.sofifa.net/players/268/774/23_60.png  ...           Right
# 1901  https://cdn.sofifa.net/players/226/045/23_60.png  ...            Left
#
#       Weak Foot Rating  Skill Moves  International Reputation  \
# 1876                 3            3                         1
# 1806                 3            3                         1
# 1478                 4            3                         1
# 1523                 4            3                         1
# 1649                 3            2                         1
# ...                ...          ...                       ...
# 9943                 3            2                         1
# 3505                 3            3                         1
# 4961                 3            2                         1
# 8254                 3            3                         1
# 1901                 3            3                         1
#
#       National Team Name             National Team Image Link  \
# 1876                   -  https://cdn.sofifa.net/flags/es.png
# 1806                   -  https://cdn.sofifa.net/flags/es.png
# 1478                   -  https://cdn.sofifa.net/flags/es.png
# 1523                   -  https://cdn.sofifa.net/flags/es.png
# 1649             Croatia  https://cdn.sofifa.net/flags/hr.png
# ...                  ...                                  ...
# 9943               Qatar  https://cdn.sofifa.net/flags/qa.png
# 3505               Qatar  https://cdn.sofifa.net/flags/qa.png
# 4961             Hungary  https://cdn.sofifa.net/flags/hu.png
# 8254               Qatar  https://cdn.sofifa.net/flags/qa.png
# 1901              Mexico  https://cdn.sofifa.net/flags/mx.png
#
#       National Team Position  National Team Jersey Number Attacking Work Rate  \
# 1876                       -                            -              Medium
# 1806                       -                            -              Medium
# 1478                       -                            -              Medium
# 1523                       -                            -              Medium
# 1649                     SUB                            5              Medium
# ...                      ...                          ...                 ...
# 9943                     SUB                           13              Medium
# 3505                      CM                           12              Medium
# 4961                      CB                            2              Medium
# 8254                     SUB                           17              Medium
# 1901                      LB                           23                High
#
#      Defensive Work Rate
# 1876              Medium
# 1806              Medium
# 1478                High
# 1523                High
# 1649                High
# ...                  ...
# 9943              Medium
# 3505              Medium
# 4961              Medium
# 8254                 Low
# 1901                 Low
#
# [18539 rows x 33 columns]
#                   Full Name Contract Until
# 1876  Jose Luís García Vayá           2032
# 1806  Jose Luís García Vayá           2032
# 1478   Jon Moncayola Tollar           2031
# 1523   Jon Moncayola Tollar           2031
# 1649           Josip Šutalo           2028
# 231     Aurélien Tchouaméni           2028

# %% [markdown]
# <font size = "5">
#
# (c) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "TotalStats"
# - If "TotalStats > 85", classification = "Top Performer"
# - If "TotalStats <= 85", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "TotalStats" in the dataset <br>
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def fn_stats(TotalStats):
    if TotalStats > 85:
        classification = "Top Performer"
    else:
        classification = "Non Top-Performer"
    return classification

fifa["player_classification"] = fifa["TotalStats"].apply(fn_stats)
display(fifa)
print(fifa["player_classification"])
# Out:
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Skill Moves  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            4
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...            4
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...            4
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...            4
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...            5
# ...                                                 ...  ...          ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...            2
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...            2
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...            2
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...            2
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            2
#
#        International Reputation  National Team Name  \
# 0                             5           Argentina
# 1                             4              France
# 2                             5              Poland
# 3                             4             Belgium
# 4                             4              France
# ...                         ...                 ...
# 18534                         1                   -
# 18535                         1                   -
# 18536                         1                   -
# 18537                         1                   -
# 18538                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 0                              10                  Low                  Low
# 1                              19               Medium               Medium
# 2                               9                 High               Medium
# 3                               7                 High                 High
# 4                              10                 High                  Low
# ...                           ...                  ...                  ...
# 18534                           -               Medium               Medium
# 18535                           -               Medium               Medium
# 18536                           -                 High               Medium
# 18537                           -               Medium               Medium
# 18538                           -               Medium               Medium
#
#       random_var player_classification
# 0       0.873788         Top Performer
# 1       0.873537         Top Performer
# 2       0.465583         Top Performer
# 3       0.783508         Top Performer
# 4       0.967540         Top Performer
# ...          ...                   ...
# 18534   0.623440         Top Performer
# 18535   0.988571         Top Performer
# 18536   0.416502         Top Performer
# 18537   0.629858         Top Performer
# 18538   0.644220         Top Performer
#
# [18539 rows x 35 columns]
# 0        Top Performer
# 1        Top Performer
# 2        Top Performer
# 3        Top Performer
# 4        Top Performer
#              ...
# 18534    Top Performer
# 18535    Top Performer
# 18536    Top Performer
# 18537    Top Performer
# 18538    Top Performer
# Name: player_classification, Length: 18539, dtype: object

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Overall" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code
regression = smf.ols(formula = 'Overall ~ Age', data = fifa)
results = model.fit()

values = results.params
print(values)
# Out:
# Intercept    49.787345
# Age           0.636467
# dtype: float64

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.4```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.4```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
# Write your own code
n = len(fifa)
fifa["random_var"] = np.random.uniform(low = 0, high = 1, size = n)
data0 = fifa.query('random_var < 0.4')
data1 = fifa.query('random_var >= 0.4')
display(data0)
display(data1)
# Out:
#        Unnamed: 0      Known As                          Full Name  Overall  \
# 12             12        H. Son                      Heung Min Son       89
# 13             13      Casemiro  Carlos Henrique Venancio Casimiro       89
# 15             15       S. Mané                         Sadio Mané       89
# 18             18       Alisson              Alisson Ramses Becker       89
# 19             19      N. Kanté                       N'Golo Kanté       89
# ...           ...           ...                                ...      ...
# 18512       18512     Li Peinan                          Peinan Li       48
# 18519       18519    T. Giraldo                      Tomas Giraldo       48
# 18522       18522      E. Singh                       Engson Singh       48
# 18524       18524    A. Brînzea                     Andreș Brînzea       48
# 18526       18526  Chen Chunxin                       Chunxin Chen       48
#
#        Potential  Value(in Euro) Positions Played Best Position  \
# 12            89       101000000            LW,LM            LW
# 13            89        86000000              CDM           CDM
# 15            89        99500000            LM,CF            LM
# 18            90        79000000               GK            GK
# 19            89        72000000           CDM,CM           CDM
# ...          ...             ...              ...           ...
# 18512         56          100000               CB            CB
# 18519         64          120000               CM           CAM
# 18522         63          110000           CAM,CM           CAM
# 18524         72          130000               GK            GK
# 18526         52           70000               CM            RM
#
#           Nationality                                        Image Link  ...  \
# 12     Korea Republic  https://cdn.sofifa.net/players/200/104/23_60.png  ...
# 13             Brazil  https://cdn.sofifa.net/players/200/145/23_60.png  ...
# 15            Senegal  https://cdn.sofifa.net/players/208/722/23_60.png  ...
# 18             Brazil  https://cdn.sofifa.net/players/212/831/23_60.png  ...
# 19             France  https://cdn.sofifa.net/players/215/914/23_60.png  ...
# ...               ...                                               ...  ...
# 18512        China PR  https://cdn.sofifa.net/players/268/969/23_60.png  ...
# 18519          Canada  https://cdn.sofifa.net/players/260/393/23_60.png  ...
# 18522           India  https://cdn.sofifa.net/players/259/649/23_60.png  ...
# 18524         Romania  https://cdn.sofifa.net/players/271/179/23_60.png  ...
# 18526        China PR  https://cdn.sofifa.net/players/255/597/23_60.png  ...
#
#        Skill Moves  International Reputation  National Team Name  \
# 12               4                         4                   -
# 13               2                         3                   -
# 15               4                         4                   -
# 18               1                         3                   -
# 19               2                         4              France
# ...            ...                       ...                 ...
# 18512            2                         1                   -
# 18519            2                         1                   -
# 18522            2                         1                   -
# 18524            1                         1                   -
# 18526            2                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 12                                       -                       -
# 13     https://cdn.sofifa.net/flags/br.png                       -
# 15                                       -                       -
# 18     https://cdn.sofifa.net/flags/br.png                       -
# 19     https://cdn.sofifa.net/flags/fr.png                     CDM
# ...                                    ...                     ...
# 18512                                    -                       -
# 18519  https://cdn.sofifa.net/flags/ca.png                       -
# 18522                                    -                       -
# 18524  https://cdn.sofifa.net/flags/ro.png                       -
# 18526                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 12                              -                 High               Medium
# 13                              -               Medium                 High
# 15                              -                 High               Medium
# 18                              -               Medium               Medium
# 19                             13               Medium                 High
# ...                           ...                  ...                  ...
# 18512                           -               Medium               Medium
# 18519                           -               Medium               Medium
# 18522                           -               Medium                  Low
# 18524                           -               Medium               Medium
# 18526                           -               Medium               Medium
#
#       random_var player_classification
# 12      0.177774         Top Performer
# 13      0.159291         Top Performer
# 15      0.046151         Top Performer
# 18      0.176867         Top Performer
# 19      0.252393         Top Performer
# ...          ...                   ...
# 18512   0.220439         Top Performer
# 18519   0.105425         Top Performer
# 18522   0.247566         Top Performer
# 18524   0.380871         Top Performer
# 18526   0.007500         Top Performer
#
# [7347 rows x 35 columns]
#        Unnamed: 0        Known As           Full Name  Overall  Potential  \
# 0               0        L. Messi        Lionel Messi       91         91
# 1               1      K. Benzema       Karim Benzema       91         91
# 2               2  R. Lewandowski  Robert Lewandowski       91         91
# 3               3    K. De Bruyne     Kevin De Bruyne       91         91
# 4               4       K. Mbappé       Kylian Mbappé       91         95
# ...           ...             ...                 ...      ...        ...
# 18534       18534      D. Collins      Darren Collins       47         56
# 18535       18535    Yang Dejiang        Dejiang Yang       47         57
# 18536       18536       L. Mullan         Liam Mullan       47         67
# 18537       18537    D. McCallion    Daithí McCallion       47         61
# 18538       18538        N. Rabha         Nabin Rabha       47         50
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 0            54000000               RW           CAM            Argentina
# 1            64000000            CF,ST            CF               France
# 2            84000000               ST            ST               Poland
# 3           107500000           CM,CAM            CM              Belgium
# 4           190500000            ST,LW            ST               France
# ...               ...              ...           ...                  ...
# 18534          110000            ST,RM           CAM  Republic of Ireland
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
# 18538           60000               LB            LB                India
#
#                                              Image Link  ...  Skill Moves  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            4
# 1      https://cdn.sofifa.net/players/165/153/23_60.png  ...            4
# 2      https://cdn.sofifa.net/players/188/545/23_60.png  ...            4
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...            4
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...            5
# ...                                                 ...  ...          ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png  ...            2
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...            2
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png  ...            2
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png  ...            2
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png  ...            2
#
#        International Reputation  National Team Name  \
# 0                             5           Argentina
# 1                             4              France
# 2                             5              Poland
# 3                             4             Belgium
# 4                             4              France
# ...                         ...                 ...
# 18534                         1                   -
# 18535                         1                   -
# 18536                         1                   -
# 18537                         1                   -
# 18538                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 0                              10                  Low                  Low
# 1                              19               Medium               Medium
# 2                               9                 High               Medium
# 3                               7                 High                 High
# 4                              10                 High                  Low
# ...                           ...                  ...                  ...
# 18534                           -               Medium               Medium
# 18535                           -               Medium               Medium
# 18536                           -                 High               Medium
# 18537                           -               Medium               Medium
# 18538                           -               Medium               Medium
#
#       random_var player_classification
# 0       0.873788         Top Performer
# 1       0.873537         Top Performer
# 2       0.465583         Top Performer
# 3       0.783508         Top Performer
# 4       0.967540         Top Performer
# ...          ...                   ...
# 18534   0.623440         Top Performer
# 18535   0.988571         Top Performer
# 18536   0.416502         Top Performer
# 18537   0.629858         Top Performer
# 18538   0.644220         Top Performer
#
# [11192 rows x 35 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping scatter plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display a scatter plot of "Potential" vs "Age" for "data0" using <br>
# ```plt.scatter()```
# - Display a scatter plot of "Potential" vs "Age" for "data1" overlapping <br>
# on top of the previous one
# - You will need to add a legend, label the axes, and the title
# - To get full points, plot the scatter plot with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., y = ... , alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" and "y" vectors instead of ```...``` <br>
# (The alpha option sets the transparency of the scatter plot)
#
# Note: The goal of this question is to illustrate that random <br>
# assignment will produce very similar scatter plots for each variable

# %%
# Write your own code
display(fifa.sort_values(by = "Age", ascending = False))


plt.scatter(x = data0["Potential"], y = data0["Age"], alpha = 0.5)
plt.scatter(x = data1["Potential"], y = data1["Age"], alpha = 0.5)
plt.legend(labels = ["Data 0", "Data 1"], title  = "Data")
plt.xlabel("Potential")
plt.ylabel("Age")
plt.title("Potential vs Age")
# Out:
#        Unnamed: 0        Known As              Full Name  Overall  Potential  \
# 592           592       G. Buffon       Gianluigi Buffon       79         79
# 13548       13548        S. Lukić           Stojan Lukić       62         62
# 3276         3276      S. Torrico      Sebastián Torrico       72         72
# 15525       15525     J. Szmatuła         Jakub Szmatuła       59         59
# 10851       10851       M. Galezo          Moisés Galezo       64         64
# ...           ...             ...                    ...      ...        ...
# 18188       18188     A. Andresen          Aske Andresen       52         73
# 18365       18365  T. Kristiansen  Thorbjørn Kristiansen       50         72
# 16813       16813       O. Megeed            Omar Megeed       57         77
# 14439       14439         W. Amey            Wisdom Amey       61         81
# 17193       17193      E. Koyuncu       Efe Arda Koyuncu       56         75
#
#        Value(in Euro) Positions Played Best Position             Nationality  \
# 592           1900000               GK            GK                   Italy
# 13548           45000               GK            GK  Bosnia and Herzegovina
# 3276           250000               GK            GK               Argentina
# 15525           25000               GK            GK                  Poland
# 10851               0               CB            CB               Venezuela
# ...               ...              ...           ...                     ...
# 18188          230000               GK            GK                 Denmark
# 18365          140000               CB            CB                  Norway
# 16813          450000           LW,CAM            RM                   Egypt
# 14439          850000               CB            CB                   Italy
# 17193          325000               CB            CB                  Turkey
#
#                                              Image Link  ...  Skill Moves  \
# 592    https://cdn.sofifa.net/players/001/179/23_60.png  ...            1
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png  ...            1
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png  ...            1
# 15525  https://cdn.sofifa.net/players/155/422/23_60.png  ...            1
# 10851  https://cdn.sofifa.net/players/265/721/23_60.png  ...            2
# ...                                                 ...  ...          ...
# 18188  https://cdn.sofifa.net/players/265/179/23_60.png  ...            1
# 18365  https://cdn.sofifa.net/players/267/732/23_60.png  ...            2
# 16813  https://cdn.sofifa.net/players/271/214/23_60.png  ...            3
# 14439  https://cdn.sofifa.net/players/269/183/23_60.png  ...            2
# 17193  https://cdn.sofifa.net/players/268/906/23_60.png  ...            2
#
#        International Reputation  National Team Name  \
# 592                           4                   -
# 13548                         1                   -
# 3276                          1                   -
# 15525                         1                   -
# 10851                         1                   -
# ...                         ...                 ...
# 18188                         1                   -
# 18365                         1                   -
# 16813                         1                   -
# 14439                         1                   -
# 17193                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 592    https://cdn.sofifa.net/flags/it.png                       -
# 13548                                    -                       -
# 3276   https://cdn.sofifa.net/flags/ar.png                       -
# 15525  https://cdn.sofifa.net/flags/pl.png                       -
# 10851  https://cdn.sofifa.net/flags/ve.png                       -
# ...                                    ...                     ...
# 18188  https://cdn.sofifa.net/flags/dk.png                       -
# 18365  https://cdn.sofifa.net/flags/no.png                       -
# 16813                                    -                       -
# 14439  https://cdn.sofifa.net/flags/it.png                       -
# 17193  https://cdn.sofifa.net/flags/tr.png                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 592                             -               Medium               Medium
# 13548                           -               Medium               Medium
# 3276                            -               Medium               Medium
# 15525                           -               Medium               Medium
# 10851                           -               Medium                 High
# ...                           ...                  ...                  ...
# 18188                           -               Medium               Medium
# 18365                           -               Medium               Medium
# 16813                           -               Medium               Medium
# 14439                           -               Medium               Medium
# 17193                           -               Medium               Medium
#
#       random_var player_classification
# 592     0.979505         Top Performer
# 13548   0.212449         Top Performer
# 3276    0.018515         Top Performer
# 15525   0.047157         Top Performer
# 10851   0.772896         Top Performer
# ...          ...                   ...
# 18188   0.010851         Top Performer
# 18365   0.685805         Top Performer
# 16813   0.518361         Top Performer
# 14439   0.912750         Top Performer
# 17193   0.282617         Top Performer
#
# [18539 rows x 35 columns]
# Text(0.5, 1.0, 'Potential vs Age')
